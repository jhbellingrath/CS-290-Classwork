# %% [markdown]
# <a href="https://colab.research.google.com/github/jhbellingrath/CS-290-Classwork/blob/main/notebooks/Gaussian_Mixtures.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.mixture import GaussianMixture
from matplotlib.colors import LogNorm

# %%
X = pd.read_csv("https://github.com/mbrudd/csci290/raw/refs/heads/main/data/penguins.csv")
Y=X['species']
X=X.drop(columns=['species'])
X=X.drop(columns=['island'])
X=X.drop(columns=['sex'])
X=X.drop(columns=['year'])
X=X.drop(3) #getting rid of the NaNs
X=X.drop(271)
X=X.reset_index(drop=True)

# %%
gm = GaussianMixture(n_components=3, n_init=10, random_state=42)
gm.fit(X)
# Out:
# GaussianMixture(n_components=3, n_init=10, random_state=42)

# %%
show_ylabels=True
clusterer=gm
resolution=1000
mins = X.min(axis=0) - 0.1
maxs = X.max(axis=0) + 0.1
xx, yy = np.meshgrid(np.linspace(mins[0], maxs[0], resolution), np.linspace(mins[1], maxs[1], resolution))
# Out:
# <ipython-input-111-4feee1fa9a95>:6: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   xx, yy = np.meshgrid(np.linspace(mins[0], maxs[0], resolution), np.linspace(mins[1], maxs[1], resolution))

# %%
Z = -clusterer.score_samples(np.c_[xx.ravel(), yy.ravel()])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but GaussianMixture was fitted with feature names
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-112-1cb31f58b46e> in <cell line: 1>()
# ----> 1 Z = -clusterer.score_samples(np.c_[xx.ravel(), yy.ravel()])
#
# /usr/local/lib/python3.10/dist-packages/sklearn/mixture/_base.py in score_samples(self, X)
#     344         """
#     345         check_is_fitted(self)
# --> 346         X = self._validate_data(X, reset=False)
#     347
#     348         return logsumexp(self._estimate_weighted_log_prob(X), axis=1)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     652
# ...

# %%
# extra code – this cells generates and saves Figure 9–16
def plot_gaussian_mixture(clusterer, X, resolution=1000, show_ylabels=True):
    mins = X.min(axis=0) - 0.1
    maxs = X.max(axis=0) + 0.1
    xx, yy = np.meshgrid(np.linspace(mins[0], maxs[0], resolution), np.linspace(mins[1], maxs[1], resolution))

    Z = -clusterer.score_samples(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)


    plt.contourf(xx, yy, Z,
                 norm=LogNorm(vmin=1.0, vmax=30.0),
                 levels=np.logspace(0, 2, 12))
    plt.contour(xx, yy, Z,
                norm=LogNorm(vmin=1.0, vmax=30.0),
                levels=np.logspace(0, 2, 12),
                linewidths=1, colors='k')

    Z = clusterer.predict(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)
    plt.contour(xx, yy, Z,
                linewidths=2, colors='r', linestyles='dashed')

    plt.plot(X[:, 0], X[:, 1], 'k.', markersize=2)
    plot_centroids(clusterer.means_, clusterer.weights_)

    plt.xlabel("$x_1$")
    if show_ylabels:
        plt.ylabel("$x_2$", rotation=0)
    else:
        plt.tick_params(labelleft=False)

plt.figure(figsize=(8, 4))

##plot_gaussian_mixture(gm, X)
plot_gaussian_mixture(X,df)

save_fig("gaussian_mixtures_plot")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-108-0deec6df2e38> in <cell line: 37>()
#      35
#      36 ##plot_gaussian_mixture(gm, X)
# ---> 37 plot_gaussian_mixture(X,df)
#      38
#      39 save_fig("gaussian_mixtures_plot")
#
# <ipython-input-108-0deec6df2e38> in plot_gaussian_mixture(clusterer, X, resolution, show_ylabels)
#       1 # extra code – this cells generates and saves Figure 9–16
#       2 def plot_gaussian_mixture(clusterer, X, resolution=1000, show_ylabels=True):
# ----> 3     mins = X.min(axis=0) - 0.1
#       4     print("hi")
#       5     maxs = X.max(axis=0) + 0.1
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in min(self, axis, skipna, numeric_only, **kwargs)
#   11641         **kwargs,
#   11642     ):
# > 11643         result = super().min(axis, skipna, numeric_only, **kwargs)
# ...

# %%
 X.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-64-ae5cd47bda90> in <cell line: 1>()
# ----> 1 X.head()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'head'
